# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# # Transaction analysis

# %%
transaction = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',  sheet_name='Transactions', header=1)
transaction.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0
# 3     1198.46         381.10                  36145.0
# 4     1765.30         709.48                  42226.0

# %%
transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
# percentage of missing data
transaction.isnull().mean()*100
# Out:
# transaction_id             0.000
# product_id                 0.000
# customer_id                0.000
# transaction_date           0.000
# online_order               1.800
# order_status               0.000
# brand                      0.985
# product_line               0.985
# product_class              0.985
# product_size               0.985
# list_price                 0.000
# standard_cost              0.985
# product_first_sold_date    0.985
# dtype: float64

# %%
transaction.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# descriptive analysis of numeric attributes
transaction.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost  product_first_sold_date
# count   19803.000000             19803.000000
# mean      556.046951             38199.776549
# std       405.955660              2875.201110
# min         7.210000             33259.000000
# 25%       215.140000             35667.000000
# 50%       507.580000             38216.000000
# 75%       795.100000             40672.000000
# max      1759.850000             42710.000000

# %%
transaction[transaction.transaction_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date]
# Index: []

# %%
# boxplot of numeric attributes
num_var = ['list_price', 'standard_cost', 'product_first_sold_date']

def num_boxplot(list, df):
    for var in list:
        sns.boxplot(y=df[var])
        plt.title(var)
        plt.show()
        
num_boxplot(num_var, transaction)

# %% [markdown]
# We have one outlier in standard_cost column

# %%
# let's investigate in standard_cost column
pd.options.display.max_columns = None
transaction.standard_cost.quantile(np.arange(0.1,1.01,0.01))
# Out:
# 0.10      99.59
# 0.11     101.58
# 0.12     108.76
# 0.13     125.07
# 0.14     131.92
#          ...
# 0.96    1516.13
# 0.97    1531.42
# 0.98    1580.47
# 0.99    1610.90
# 1.00    1759.85
# Name: standard_cost, Length: 91, dtype: float64

# %%
# list of customer id having standard cost = 1759.85
list = transaction[transaction.standard_cost == 1759.85]['customer_id'].to_list()
list
# Out:
# [3473,
#  2135,
#  3380,
#  720,
#  1535,
#  2383,
#  1147,
#  1060,
#  860,
#  2572,
#  2796,
#  2548,
#  2618,
#  1103,
#  3477,
#  1911,
#  2567,
#  482,
#  341,
#  1051,
#  1438,
#  778,
#  3042,
#  637,
#  1331,
#  802,
#  1449,
#  1052,
#  2339,
#  234,
#  893,
#  1587,
#  2666,
#  375,
#  735,
#  292,
#  638,
#  3151,
#  2114,
#  2404,
#  525,
#  2690,
#  2392,
#  1690,
#  1597,
#  710,
#  1119,
#  1581,
#  810,
#  172,
#  1069,
#  2945,
#  309,
#  3483,
#  3071,
#  962,
#  1038,
#  2509,
#  134,
#  1522,
#  1506,
#  1623,
#  343,
#  3015,
#  2983,
#  601,
#  2088,
#  1876,
#  884,
#  1876,
#  829,
#  334,
#  742,
#  1324,
#  2762,
#  1982,
#  136,
#  1119,
#  498,
#  1237,
#  565,
#  2921,
#  140,
#  776,
#  3074,
#  3426,
#  1635,
#  38,
#  3066,
#  2063,
#  1913,
#  718,
#  2376,
#  1048,
#  484,
#  34,
#  2237,
#  1177,
#  576,
#  1334,
#  1575,
#  217,
#  2913,
#  1129,
#  2609,
#  2344,
#  1889,
#  1076,
#  1918,
#  1598,
#  286,
#  640,
#  684,
#  2185,
#  2144,
#  2537,
#  2885,
#  3266,
#  1500,
#  2916,
#  2561,
#  3187,
#  1512,
#  2562,
#  823,
#  2698,
#  2182,
#  3203,
#  3113,
#  1302,
#  3411,
#  714,
#  142,
#  1482,
#  2529,
#  382,
#  2788,
#  2615,
#  1129,
#  1052,
#  3252,
#  844,
#  2751,
#  1374,
#  884,
#  260,
#  443,
#  906,
#  2525,
#  1290,
#  1672,
#  3228,
#  1045,
#  3453,
#  252,
#  1429,
#  2880,
#  2498,
#  1590,
#  973,
#  3468,
#  3332,
#  1678,
#  1202,
#  2076,
#  2686,
#  1357,
#  2816,
#  1492,
#  2072,
#  2401,
#  975,
#  1902,
#  1773,
#  3294,
#  328,
#  3247,
#  3442,
#  1504,
#  749,
#  1595,
#  2942,
#  2164,
#  1375,
#  1142,
#  2866,
#  2617,
#  1876,
#  630,
#  2082,
#  3411,
#  844,
#  54,
#  1841,
#  2640]

# %%
pd.DataFrame(list).to_csv('ls_custId.csv')

# %%
cat_var = [var for var in transaction.columns if transaction[var].dtypes == 'object']

def cardinality(list, df):
    for var in list:
        print(var,'cardinality ->', df[var].nunique())
        print(df[var].unique(),'\n')
        
cardinality(cat_var, transaction)
# Out:
# order_status cardinality -> 2
# ['Approved' 'Cancelled']
#
# brand cardinality -> 6
# ['Solex' 'Trek Bicycles' 'OHM Cycles' 'Norco Bicycles' 'Giant Bicycles'
#  'WeareA2B' nan]
#
# product_line cardinality -> 4
# ['Standard' 'Road' 'Mountain' 'Touring' nan]
#
# product_class cardinality -> 3
# ['medium' 'low' 'high' nan]
#
# product_size cardinality -> 3
# ['medium' 'large' 'small' nan]

# %%
#plt.figure(figsize=(16,4))
#transaction['transaction_date'].hist(bins=30)

def year_analyz(df, var):
    plt.figure(figsize=(16,4))
    sns.countplot(pd.DatetimeIndex(df[var]).year)
    plt.xticks(rotation = 90)
    plt.show()
    
year_analyz(transaction, 'transaction_date')

# %%
plt.figure(figsize=(16,4))
sns.countplot(pd.DatetimeIndex(transaction['transaction_date']).month)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(transaction.online_order)
plt.title('count of online order')
# Out:
# Text(0.5, 1.0, 'count of online order')

# %%
transaction.corr()
# Out:
#                          transaction_id  product_id  customer_id  \
# transaction_id                 1.000000   -0.011486     0.001753
# product_id                    -0.011486    1.000000     0.004278
# customer_id                    0.001753    0.004278     1.000000
# online_order                   0.003394   -0.004233     0.001616
# list_price                    -0.006154    0.090066     0.009306
# standard_cost                 -0.003291    0.038765     0.005365
# product_first_sold_date        0.004835   -0.052961    -0.001521
#
#                          online_order  list_price  standard_cost  \
# transaction_id               0.003394   -0.006154      -0.003291
# product_id                  -0.004233    0.090066       0.038765
# customer_id                  0.001616    0.009306       0.005365
# online_order                 1.000000   -0.000295       0.006934
# list_price                  -0.000295    1.000000       0.551539
# standard_cost                0.006934    0.551539       1.000000
# product_first_sold_date      0.000902    0.059367       0.031088
#
#                          product_first_sold_date
# transaction_id                          0.004835
# product_id                             -0.052961
# customer_id                            -0.001521
# online_order                            0.000902
# list_price                              0.059367
# standard_cost                           0.031088
# product_first_sold_date                 1.000000

# %%
sns.heatmap(transaction.corr())

# %%
sns.scatterplot(transaction.list_price, transaction.standard_cost)

# %% [markdown]
# # New customer list analysis

# %%
nw_cust_ls = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',  sheet_name='NewCustomerList', header=1)
nw_cust_ls.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# 1      Mass Customer                  N       No  ...    NSW  Australia
# 2  Affluent Customer                  N       No  ...    VIC  Australia
# 3  Affluent Customer                  N      Yes  ...    QLD  Australia
# 4  Affluent Customer                  N       No  ...    NSW  Australia
#
#    property_valuation Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0                   6        0.56      0.7000       0.8750     0.743750
# 1                  11        0.89      0.8900       1.1125     0.945625
# 2                   5        1.01      1.0100       1.0100     1.010000
# 3                   1        0.87      1.0875       1.0875     1.087500
# 4                   9        0.52      0.5200       0.6500     0.650000
#
#    Unnamed: 20  Rank     Value
# 0            1     1  1.718750
# 1            1     1  1.718750
# 2            1     1  1.718750
# 3            4     4  1.703125
# 4            4     4  1.703125
#
# [5 rows x 23 columns]

# %% [markdown]
# 5 columns are unnamed

# %%
nw_cust_ls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
#  11  address                              1000 non-null   object
#  12  postcode                             1000 non-null   int64
#  13  state                                1000 non-null   object
#  14  country                              1000 non-null   object
#  15  property_valuation                   1000 non-null   int64
#  16  Unnamed: 16                          1000 non-null   float64
#  17  Unnamed: 17                          1000 non-null   float64
#  18  Unnamed: 18                          1000 non-null   float64
#  19  Unnamed: 19                          1000 non-null   float64
#  20  Unnamed: 20                          1000 non-null   int64
#  21  Rank                                 1000 non-null   int64
#  22  Value                                1000 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(11)
# memory usage: 179.8+ KB

# %%
sns.heatmap(nw_cust_ls.corr())

# %%
nw_cust_ls.isnull().mean()*100
# Out:
# first_name                              0.0
# last_name                               2.9
# gender                                  0.0
# past_3_years_bike_related_purchases     0.0
# DOB                                     1.7
# job_title                              10.6
# job_industry_category                  16.5
# wealth_segment                          0.0
# deceased_indicator                      0.0
# owns_car                                0.0
# tenure                                  0.0
# address                                 0.0
# postcode                                0.0
# state                                   0.0
# country                                 0.0
# property_valuation                      0.0
# Unnamed: 16                             0.0
# Unnamed: 17                             0.0
# Unnamed: 18                             0.0
# Unnamed: 19                             0.0
# Unnamed: 20                             0.0
# Rank                                    0.0
# Value                                   0.0
# dtype: float64

# %%
nw_cust_ls.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
nw_cust_ls[nw_cust_ls[['first_name', 'last_name']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20, Rank, Value]
# Index: []

# %%
cat_var = [var for var in nw_cust_ls.columns if nw_cust_ls[var].dtypes == 'object']
cat_var = cat_var[2:]
cat_var
# Out:
# ['gender',
#  'job_title',
#  'job_industry_category',
#  'wealth_segment',
#  'deceased_indicator',
#  'owns_car',
#  'address',
#  'state',
#  'country']

# %%
cardinality(cat_var, nw_cust_ls)
# Out:
# gender cardinality -> 3
# ['Male' 'Female' 'U']
#
# job_title cardinality -> 184
# ['General Manager' 'Structural Engineer' 'Senior Cost Accountant'
#  'Account Representative III' 'Financial Analyst'
#  'Assistant Media Planner' 'Compensation Analyst'
#  'Human Resources Assistant II' 'Speech Pathologist'
#  'Accounting Assistant IV' 'Programmer Analyst I'
#  'Environmental Specialist' 'Human Resources Manager' 'VP Marketing'
#  'Clinical Specialist' nan 'Associate Professor' 'Actuary'
#  'Internal Auditor' 'Programmer I' 'Quality Engineer'
#  'Quality Control Specialist' 'Account Executive' 'Engineer II' 'Nurse'
#  'Librarian' 'Paralegal' 'Assistant Manager' 'Senior Quality Engineer'
#  'Recruiting Manager' 'Design Engineer'
#  'Business Systems Development Analyst' 'VP Quality Control'
#  'Cost Accountant' 'Product Engineer' 'Social Worker'
#  'Payment Adjustment Coordinator' 'Marketing Assistant' 'Recruiter'
#  'VP Product Management' 'Media Manager III' 'Developer I'
#  'Senior Financial Analyst' 'Electrical Engineer' 'Accountant IV'
#  'Executive Secretary' 'Account Representative I' 'Dental Hygienist'
#  'GIS Technical Architect' 'Assistant Professor'
#  'Mechanical Systems Engineer' 'Budget/Accounting Analyst IV'
#  'Research Nurse' 'Computer Systems Analyst IV' 'Analyst Programmer'
#  'Desktop Support Technician' 'Editor' 'Biostatistician IV'
#  'Database Administrator III' 'Engineer III' 'Physical Therapy Assistant'
#  'Director of Sales' 'Teacher' 'Human Resources Assistant IV'
#  'Nurse Practicioner' 'Structural Analysis Engineer' 'Marketing Manager'
#  'Staff Accountant IV' 'VP Sales' 'Accountant III' 'Sales Representative'
#  'Food Chemist' 'Staff Scientist' 'Geologist IV'
#  'Information Systems Manager' 'Junior Executive'
#  'Automation Specialist II' 'Software Consultant' 'Civil Engineer'
#  'Geological Engineer' 'Graphic Designer' 'Staff Accountant II'
#  'Community Outreach Specialist' 'Programmer Analyst II' 'Pharmacist'
#  'Senior Editor' 'Sales Associate' 'Developer II' 'Staff Accountant I'
#  'Environmental Tech' 'Account Coordinator' 'Health Coach II'
#  'Programmer Analyst III' 'Geologist III' 'Senior Developer'
#  'Account Representative II' 'Help Desk Technician'
#  'Research Assistant IV' 'Research Associate' 'Computer Systems Analyst I'
#  'Account Representative IV' 'Safety Technician I'
#  'Analog Circuit Design manager' 'Senior Sales Associate'
#  'Research Assistant II' 'Chief Design Engineer' 'Legal Assistant'
#  'Occupational Therapist' 'Statistician I' 'Technical Writer'
#  'Health Coach IV' 'Media Manager II' 'Professor' 'Safety Technician II'
#  'Software Test Engineer IV' 'Nuclear Power Engineer'
#  'Software Engineer II' 'Engineer IV' 'Database Administrator II'
#  'Chemical Engineer' 'Office Assistant II' 'Database Administrator I'
#  'Research Assistant I' 'Financial Advisor' 'Systems Administrator I'
#  'Systems Administrator IV' 'Operator' 'Office Assistant I'
#  'Software Engineer I' 'Programmer III' 'Media Manager I'
#  'Data Coordiator' 'Web Developer IV' 'Registered Nurse'
#  'Media Manager IV' 'Programmer II' 'Computer Systems Analyst II'
#  'Web Designer I' 'Human Resources Assistant I' 'Help Desk Operator'
#  'Systems Administrator III' 'Software Engineer III' 'Developer IV'
#  'Tax Accountant' 'Automation Specialist IV' 'VP Accounting'
#  'Accountant II' 'Administrative Assistant II' 'Programmer IV'
#  'Web Designer IV' 'Administrative Officer' 'Office Assistant IV'
#  'Accounting Assistant III' 'Accounting Assistant I'
#  'Research Assistant III' 'Web Developer II' 'Statistician III'
#  'Programmer Analyst IV' 'Accountant I' 'Project Manager'
#  'Budget/Accounting Analyst II' 'Automation Specialist III'
#  'Administrative Assistant I' 'Engineer I' 'Health Coach III'
#  'Statistician II' 'Developer III' 'Accounting Assistant II'
#  'Database Administrator IV' 'Budget/Accounting Analyst III'
#  'Software Test Engineer I' 'Health Coach I' 'Safety Technician IV'
#  'Computer Systems Analyst III' 'Budget/Accounting Analyst I'
#  'Staff Accountant III' 'Human Resources Assistant III' 'Statistician IV'
#  'Automation Specialist I' 'Systems Administrator II'
#  'Software Test Engineer II' 'Software Test Engineer III' 'Geologist I'
#  'Web Designer II' 'Web Developer I']
#
# job_industry_category cardinality -> 9
# ['Manufacturing' 'Property' 'Financial Services' 'Entertainment' 'Retail'
#  'IT' 'Telecommunications' 'Health' nan 'Argiculture']
#
# wealth_segment cardinality -> 3
# ['Mass Customer' 'Affluent Customer' 'High Net Worth']
#
# deceased_indicator cardinality -> 1
# ['N']
#
# owns_car cardinality -> 2
# ['Yes' 'No']
#
# address cardinality -> 1000
# ['45 Shopko Center' '14 Mccormick Park' '5 Colorado Crossing'
#  '207 Annamark Plaza' '115 Montana Place' '89105 Pearson Terrace'
#  '7 Nevada Crossing' '85 Carioca Point' '717 West Drive'
#  '80 Scofield Junction' '3682 Crowley Point' '3 Golden Leaf Point'
#  '0484 North Avenue' '0591 Anzinger Circle' '39 Kedzie Pass'
#  '64 Granby Parkway' '610 Swallow Street' '61 4th Street'
#  '1550 Russell Way' '193 North Point' '321 Raven Plaza'
#  '656 Fuller Street' '1562 Merchant Street' '663 8th Parkway'
#  '67 Shelley Street' '75 Cordelia Trail' '51 Hooker Court'
#  '1859 Forest Circle' '44557 Rutledge Court' '11184 East Drive'
#  '555 Hermina Avenue' '8 Novick Trail' '74 Welch Pass' '3 Pleasure Drive'
#  '8 Dennis Point' '41042 Lotheville Crossing' '2330 Butternut Trail'
#  '240 Acker Avenue' '04 Dexter Way' '011 Northland Trail'
#  '8 Grayhawk Circle' '44 Darwin Lane' '2548 Arrowood Pass'
#  '938 Ilene Road' '6 Melby Center' '08708 Moulton Park'
#  '306 Clemons Junction' '18 Grim Road' '169 Bashford Drive'
#  '3 Vermont Lane' '998 Gale Park' '64 Mcguire Trail' '74127 Blaine Point'
#  '31756 Meadow Valley Lane' '293 Mayfield Street' '261 Grayhawk Way'
#  '2 Schlimgen Terrace' '76733 Sunbrook Terrace' '683 Florence Way'
#  '7232 Fulton Parkway' '06936 Bobwhite Circle' '283 Acker Drive'
#  '9 Mosinee Parkway' '45 Becker Place' '27 Karstens Crossing'
#  '9630 Cottonwood Avenue' '989 Graedel Terrace' '76 Bartelt Center'
#  '29778 Mendota Drive' '69 Algoma Center' '8288 Lyons Way'
#  '4185 Florence Trail' '9608 Heffernan Drive' '9 Union Center'
#  '800 Emmet Park' '12351 Spenser Pass' '4 Valley Edge Plaza'
#  '1601 Rutledge Lane' '0 Mockingbird Plaza' '1665 Kenwood Center'
#  '5 4th Center' '92214 Spenser Road' '5186 Main Trail'
#  '564 Forest Dale Avenue' '83 Old Gate Point' '387 Dixon Alley'
#  '411 Twin Pines Way' '12 Arapahoe Park' '4915 Debra Center'
#  '76 Sunnyside Avenue' '1 Talisman Avenue' '91164 Washington Terrace'
#  '74 Carpenter Street' '6776 Anderson Center' '1 Orin Hill'
#  '88 Annamark Avenue' '37439 High Crossing Circle' '5 Nevada Point'
#  '67 Grayhawk Circle' '0 Meadow Ridge Street' '5 Quincy Street'
#  '13025 Johnson Plaza' '966 Sunnyside Center' '802 Mallory Park'
#  '93 Judy Drive' '94 Manitowish Court' '5013 Erie Crossing'
#  '540 Sachs Road' '422 Forster Circle' '4275 Bluestem Pass'
#  '6 Anderson Junction' '276 Westend Road' '69 Garrison Point'
#  '65 Milwaukee Hill' '4252 Dovetail Pass' '56 Riverside Street'
#  '7 Cascade Park' '29307 Russell Avenue' '3 Mcguire Crossing'
#  '6 Golf View Alley' '83716 Russell Lane' '265 Stephen Trail'
#  '2 Charing Cross Trail' '8350 Moulton Terrace' '578 Waywood Circle'
#  '9722 Northport Way' '7026 Katie Lane' '8 Eggendart Pass'
#  '1 Bluejay Place' '28970 Monument Lane' '235 Mendota Court'
#  '49309 Redwing Lane' '367 Bay Point' '932 Glendale Avenue'
#  '492 Waywood Lane' '12683 Mifflin Point' '6160 Weeping Birch Hill'
#  '7 Oakridge Lane' '0 Dexter Parkway' '75813 Lawn Lane'
#  '74613 Northport Park' '68 Karstens Pass' '87254 Hermina Pass'
#  '801 Atwood Alley' '2 Morrow Alley' '92934 Mallory Trail'
#  '90820 Thackeray Street' '48 Ludington Plaza' '49185 Derek Circle'
#  '0721 Meadow Ridge Pass' '115 Westridge Road' '7 Myrtle Lane'
#  '7795 Memorial Drive' '24695 Boyd Road' '95306 John Wall Avenue'
#  '6704 Pine View Lane' '98158 Alpine Point' '33652 Lyons Alley'
#  '8 Debs Road' '101 Starling Pass' '35151 Bunker Hill Crossing'
#  '2093 Amoth Pass' '57343 Eagan Avenue' '83 Armistice Terrace'
#  '5388 Burrows Alley' '5612 Toban Point' '65 Ridge Oak Court'
#  '74 Russell Terrace' '255 Loeprich Lane' '67 Northport Avenue'
#  '823 Wayridge Trail' '5 Golf Terrace' '40809 Truax Way'
#  '1398 Burning Wood Way' '3920 Swallow Junction' '4 Warner Park'
#  '534 Lien Lane' '48 Shoshone Park' '170 Briar Crest Place'
#  '0193 Northland Street' '5219 Pearson Drive' '6156 Summit Center'
#  '803 Badeau Point' '735 Westridge Road' '1190 Hanson Street'
#  '370 Division Junction' '90 Northport Hill' '77785 Veith Lane'
#  '232 Knutson Park' '25805 Eagan Place' '743 Debra Court'
#  '6966 Delladonna Street' '98221 Pennsylvania Place' '307 Knutson Center'
#  '593 Alpine Drive' '45788 Stang Plaza' '96515 Di Loreto Pass'
#  '8625 Dakota Plaza' '02 Hoffman Road' '496 Logan Center'
#  '6065 Talisman Crossing' '72 Eliot Place' '67 Bluejay Plaza'
#  '518 Paget Hill' '87107 Shelley Crossing' '3 Mallory Circle'
#  '1582 Bashford Drive' '3 Homewood Park' '06 Old Gate Park'
#  '49 Surrey Point' '59254 Northland Alley' '4 North Drive'
#  '89 Parkside Street' '7 Hazelcrest Place' '013 David Junction'
#  '840 Graceland Street' '6 Lotheville Trail' '890 Truax Lane'
#  '72922 Cambridge Terrace' '60461 Esch Avenue' '6 Novick Alley'
#  '76 Donald Trail' '1607 Westridge Drive' '3630 Dawn Crossing'
#  '29007 Dapin Street' '68 Fairfield Street' '6 Iowa Center'
#  '5 Briar Crest Road' '945 Bobwhite Court' '2 Glendale Center'
#  '21824 Northridge Alley' '68 Anthes Park' '3 Anthes Court'
#  '036 Redwing Street' '92 Petterle Place' '72008 7th Avenue'
#  '87 Sheridan Junction' '811 Melrose Park' '2 Logan Avenue' '538 Gina Way'
#  '52761 Portage Crossing' '8 Fieldstone Street' '8957 Anhalt Alley'
#  '5 High Crossing Junction' '75760 Toban Junction' '178 Waxwing Trail'
#  '8648 Green Alley' '08912 Carberry Place' '720 Menomonie Crossing'
#  '0686 Hallows Trail' '6668 Blue Bill Park Plaza' '06 Dwight Park'
#  '5202 Crowley Place' '14709 Portage Avenue' '895 Glendale Park'
#  '0474 Bowman Hill' '652 Fuller Terrace' '5356 Sugar Plaza'
#  '7 Schiller Point' '9193 Prairieview Drive' '13272 Basil Avenue'
#  '29 Aberg Crossing' '4 Monterey Road' '416 Lighthouse Bay Lane'
#  '05475 Elgar Place' '343 Lakewood Center' '47 Kim Terrace'
#  '590 Hagan Parkway' '94694 Eagle Crest Terrace' '261 Orin Center'
#  '667 Waxwing Plaza' '83509 Delaware Street' '88 Mifflin Pass'
#  '10 Dexter Park' '3 Sundown Hill' '655 Glendale Trail'
#  '39192 Glendale Alley' '7307 Lake View Crossing' '1199 Express Plaza'
#  '1 Namekagon Point' '602 Meadow Vale Lane' '6784 Spohn Alley'
#  '67 Shelley Crossing' '07 Dayton Court' '351 Sunfield Lane'
#  '8427 Moulton Place' '984 Del Sol Junction' '3 Pepper Wood Hill'
#  '8737 Scoville Center' '385 Montana Place' '3 Surrey Court'
#  '2 Magdeline Street' '93235 Hoard Trail' '356 Carberry Avenue'
#  '71 Ludington Center' '2116 Continental Terrace' '2 7th Way'
#  '7 Elgar Road' '00003 Hoffman Pass' '71 Stone Corner Avenue'
#  '0 Esker Avenue' '61825 Debs Terrace' '11 Oak Terrace' '7 Michigan Hill'
#  '8 Randy Park' '0 Mayfield Parkway' '57903 Hanson Parkway'
#  '763 Ridgeway Place' '99 Westend Court' '5 Caliangt Center'
#  '4472 Washington Junction' '31675 Corry Way' '4882 Dakota Center'
#  '4 Warner Circle' '4 Manufacturers Crossing' '016 Westport Park'
#  '19 Debs Parkway' '665 Sachs Way' '4110 Mifflin Center'
#  '62 Spaight Center' '3 Express Lane' '7353 Mallard Junction'
#  '066 Warner Trail' '52752 Barby Hill' '57025 New Castle Street'
#  '0 Stoughton Park' '49 Jana Point' '7 Fordem Point' '797 Westend Street'
#  '5316 Farwell Hill' '770 Crest Line Parkway' '50 American Street'
#  '4793 Mcbride Pass' '01124 Dottie Lane' '42681 Carey Alley'
#  '2941 Talisman Alley' '990 Hoffman Avenue' '5 Summer Ridge Court'
#  '102 Charing Cross Terrace' '5 Trailsway Avenue' '23694 Leroy Place'
#  '53 Memorial Street' '691 Valley Edge Alley' '60073 Pankratz Pass'
#  '8 Schlimgen Drive' '0237 Mallard Place' '69710 Northfield Center'
#  '1 Kinsman Crossing' '40553 Rigney Avenue' '48578 Farmco Park'
#  '91634 Badeau Crossing' '391 Old Shore Lane' '28 Golf View Terrace'
#  '0197 Sachs Avenue' '48297 Stuart Circle' '67 Heath Circle'
#  '3 Sheridan Lane' '04 Oakridge Plaza' '78 Clarendon Drive'
#  '335 Cambridge Hill' '5675 Burning Wood Trail' '4597 Marcy Point'
#  '9 Walton Way' '27429 Dottie Plaza' '42 Donald Hill' '3 Hoepker Parkway'
#  '19561 Express Street' '41 Kropf Road' '0516 Fremont Point'
#  '7872 South Junction' '81 Donald Parkway' '105 Carpenter Court'
#  '58231 Tomscot Plaza' '3 Loeprich Point' '5773 Acker Way'
#  '540 Katie Street' '9495 Jenna Way' '66 Ruskin Parkway'
#  '9736 Mitchell Pass' '9 Springview Terrace' '1914 Oakridge Place'
#  '179 Anzinger Center' '62 Melrose Court' '84650 Novick Point'
#  '5 Hoard Parkway' '376 Talmadge Street' '5979 Green Ridge Way'
#  '2972 Holy Cross Crossing' '89 Riverside Court' '540 Forest Run Plaza'
#  '817 Bunker Hill Place' '4669 Troy Place' '02 Roth Drive'
#  '7 Northridge Court' '5735 Starling Plaza' '97 Transport Plaza'
#  '67183 Anniversary Parkway' '2 Emmet Parkway' '61926 Tomscot Hill'
#  '07 Susan Lane' '43094 Kedzie Pass' '678 Lyons Trail'
#  '1832 Burning Wood Place' '5642 Debs Terrace' '73 Riverside Trail'
#  '05 Everett Trail' '082 Welch Lane' '72 Mccormick Circle'
#  '15669 Arizona Trail' '79 Armistice Parkway' '330 Melby Terrace'
#  '2637 Monument Trail' '37919 Old Gate Park' '00 Judy Terrace'
#  '79 Armistice Junction' '7 Clemons Circle' '6455 Mayfield Street'
#  '7873 Meadow Vale Plaza' '45 Banding Hill' '53 Moulton Avenue'
#  '7 Sauthoff Park' '9082 Waywood Avenue' '30049 Brown Road'
#  '7 Huxley Trail' '3 Service Center' '0627 Golf Center'
#  '24960 Shopko Crossing' '43 Stoughton Drive' '247 Blue Bill Park Parkway'
#  '2 David Pass' '3867 Barby Hill' '52 Bobwhite Court' '32249 Sycamore Way'
#  '3 Roth Junction' '72423 Surrey Street' '76 Green Ridge Drive'
#  '9 Glacier Hill Circle' '91281 Transport Center' '11 Paget Road'
#  '3686 Waubesa Way' '6 Killdeer Way' '737 Service Lane'
#  '253 Katie Junction' '481 Moulton Place' '3864 Sheridan Alley'
#  '61416 Karstens Place' '0 Union Parkway' '4 Lukken Lane'
#  '1507 Schlimgen Trail' '4 Meadow Ridge Place' '31 Melody Circle'
#  '96 Rutledge Drive' '2905 Towne Place' '638 Caliangt Avenue'
#  '9645 Moose Terrace' '7 Messerschmidt Crossing' '005 Loeprich Way'
#  '3653 Steensland Road' '56 Comanche Terrace' '66 Merry Court'
#  '92 Ludington Street' '37 Rigney Park' '0796 Barnett Plaza'
#  '415 Rockefeller Trail' '846 Loftsgordon Crossing' '9 Ridgeview Avenue'
#  '6218 Delladonna Parkway' '095 Glacier Hill Circle'
#  '057 Victoria Crossing' '0 Memorial Road' '409 Starling Lane'
#  '36963 Pierstorff Terrace' '8069 Sunbrook Way' '9 Hovde Way'
#  '94 Barby Lane' '0492 Kings Street' '1 Fair Oaks Alley'
#  '780 Norway Maple Hill' '625 Mandrake Junction' '1037 Roth Park'
#  '315 Center Park' '1 Graceland Plaza' '98555 Victoria Hill'
#  '31121 Pierstorff Center' '59 Garrison Terrace' '2763 Buhler Circle'
#  '309 Maple Wood Pass' '777 Fairfield Court' '99 Quincy Parkway'
#  '902 Westend Lane' '9 Rieder Junction' '734 Veith Way' '0800 Dahle Alley'
#  '5 Macpherson Drive' '07 Boyd Drive' '427 Oak Avenue' '390 Express Plaza'
#  '703 Ludington Plaza' '7 Dayton Circle' '79 Manufacturers Plaza'
#  '600 Artisan Drive' '0 Veith Way' '2336 Continental Point'
#  '535 Corben Point' '1690 Forster Place' '54 6th Trail'
#  '16 Pepper Wood Junction' '4 Arapahoe Terrace' '540 Farragut Avenue'
#  '938 Bartillon Hill' '612 Annamark Center' '18 Sage Plaza'
#  '4 Randy Street' '05 Corry Center' '1 South Street' '4810 Kim Park'
#  '80388 Ryan Place' '1092 Kinsman Parkway' '1 Bluejay Court'
#  '7 Maple Wood Plaza' '12 Eastlawn Terrace' '24929 Spaight Junction'
#  '846 Daystar Lane' '36 Golf Course Circle' '0 Nelson Crossing'
#  '93264 Almo Plaza' '2109 Shoshone Court' '355 Roxbury Lane'
#  '2 Warrior Crossing' '08470 Kingsford Lane' '16898 Donald Plaza'
#  '3128 Mallory Pass' '799 Luster Road' '53 Dryden Trail'
#  '5512 Ronald Regan Hill' '72 Melrose Street' '3460 Dapin Street'
#  '5 Hovde Lane' '4 Gale Center' '5263 Stone Corner Crossing'
#  '0439 Mandrake Park' '069 Hoard Pass' '89 Green Ridge Point'
#  '8 Cardinal Junction' '240 Main Hill' '67081 Burrows Center'
#  '0 Kipling Way' '1 Raven Way' '261 Holy Cross Park' '891 Ohio Terrace'
#  '1408 Hovde Circle' '50897 Northfield Road' '596 Boyd Park'
#  '8 Fordem Place' '656 Kennedy Crossing' '2 Jackson Place'
#  '39408 Manufacturers Road' '168 Schlimgen Center' '8 Kim Avenue'
#  '920 Cambridge Way' '4 Schlimgen Trail' '31 Mccormick Court'
#  '65 Milwaukee Lane' '76 Mendota Park' '26667 Rigney Place'
#  '898 Muir Court' '88093 Pierstorff Plaza' '3319 Anthes Crossing'
#  '16 Mosinee Place' '197 Northport Plaza' '10236 Mifflin Avenue'
#  '5287 Clarendon Plaza' '38407 Sutteridge Circle' '423 Holy Cross Lane'
#  '0307 Namekagon Crossing' '743 Stuart Terrace' '1478 Oak Valley Park'
#  '8970 Anhalt Junction' '563 Waywood Park' '9313 Mayer Street'
#  '2978 Mccormick Center' '527 Jay Trail' '6 Loftsgordon Pass'
#  '9940 Manley Drive' '0736 West Crossing' '95796 Mcbride Drive'
#  '20187 Loomis Court' '17393 Colorado Hill' '65 Rutledge Parkway'
#  '02023 Loeprich Drive' '9107 Pine View Plaza' '822 Di Loreto Junction'
#  '2712 Namekagon Crossing' '32 Hazelcrest Court' '9 Forster Circle'
#  '07226 Anzinger Avenue' '936 Porter Lane' '6 Havey Pass' '882 Toban Lane'
#  '844 Forster Place' '42590 Bellgrove Court' '6060 Veith Crossing'
#  '25 Lakeland Point' '21667 Randy Crossing' '608 Dapin Court'
#  '8738 Lukken Terrace' '8634 Wayridge Pass' '5 Homewood Road'
#  '7 Dunning Avenue' '67 Beilfuss Plaza' '976 Roxbury Alley' '2 Main Lane'
#  '6115 Forest Crossing' '432 Ronald Regan Court' '8600 Forster Lane'
#  '6692 Independence Way' '770 Farmco Point' '602 Toban Center'
#  '74 Shopko Pass' '804 Washington Point' '97 Merrick Center'
#  '29 Tennyson Alley' '8194 Lien Street' '9503 New Castle Street'
#  '0 Emmet Trail' '7 Spaight Drive' '45000 Randy Court' '65 David Pass'
#  '7 Golden Leaf Avenue' '43 Dayton Drive' '5 Dryden Road'
#  '14183 Iowa Center' '95 Del Mar Court' '98 Shoshone Road'
#  '7199 Springview Parkway' '045 Magdeline Court' '5 Hoard Trail'
#  '93 Scofield Pass' '2 Ridgeway Avenue' '29 Maple Trail'
#  '7 Brentwood Circle' '28 Hazelcrest Drive' '01 Reindahl Circle'
#  '5880 Hauk Street' '0 Larry Park' '69 Sunfield Terrace'
#  '7513 Swallow Drive' '058 Morningstar Center' '0689 Melby Park'
#  '3 Spohn Circle' '91 Calypso Trail' '43863 Victoria Lane'
#  '54782 Lake View Parkway' '48971 Marquette Point' '99 Sherman Parkway'
#  '381 Emmet Terrace' '7 Beilfuss Road' '37068 Montana Street'
#  '7 Elgar Hill' '36506 Bartillon Point' '8 Scott Drive' '653 2nd Park'
#  '22 Shelley Plaza' '504 Stuart Pass' '5 Red Cloud Place'
#  '264 Valley Edge Pass' '5 Southridge Hill' '539 Graceland Pass'
#  '22435 Barnett Court' '46057 Harbort Hill' '2 Shasta Place'
#  '77608 Donald Center' '0433 La Follette Road' '8593 Prairie Rose Way'
#  '179 Carey Terrace' '3 Ruskin Hill' '87 Crescent Oaks Alley'
#  '08822 Duke Road' '5 Schurz Street' '344 Darwin Junction'
#  '320 Acker Drive' '2874 Bay Hill' '3 Sunbrook Alley' '34 Jay Hill'
#  '78 Bluestem Road' '0 Express Lane' '077 Hansons Point'
#  '23737 Bartillon Street' '2 Anniversary Trail' '05 Ronald Regan Alley'
#  '738 Spaight Drive' '8 Bunker Hill Court' '59846 2nd Pass'
#  '3745 Thierer Trail' '11121 Jackson Crossing' '1 Elgar Alley'
#  '32834 Caliangt Way' '27185 Fisk Drive' '2 Harper Junction'
#  '7 Caliangt Street' '5331 Ilene Parkway' '1009 Roxbury Point'
#  '660 Carey Avenue' '25 Oneill Alley' '2 Golden Leaf Parkway'
#  '18 Dottie Park' '85 Badeau Pass' '784 Lotheville Court'
#  '57568 Northview Junction' '283 Golf View Lane' '7 Johnson Hill'
#  '22580 Doe Crossing Drive' '96081 Lakewood Hill' '6634 Old Gate Parkway'
#  '72 Lukken Crossing' '6 Meadow Ridge Pass' '290 Menomonie Circle'
#  '6 Sutherland Parkway' '1 Oriole Crossing' '51837 Canary Center'
#  '43030 Carberry Way' '0 Bay Drive' '6 Anzinger Pass' '19453 Ramsey Point'
#  '1861 Chive Court' '9 Westerfield Point' '3 Redwing Center'
#  '189 Bayside Court' '174 Farwell Point' '356 Pennsylvania Point'
#  '62 Dryden Junction' '25 Westerfield Road' '64 Armistice Point'
#  '74 Everett Court' '38 Nobel Lane' '6936 Homewood Avenue'
#  '8 Crowley Center' '44 Ronald Regan Parkway' '174 Lotheville Crossing'
#  '8 Bluejay Road' '4286 Rowland Circle' '44 Thompson Center'
#  '70360 Onsgard Plaza' '53870 Jay Pass' '417 Killdeer Alley'
#  '28 Prentice Trail' '216 Bultman Park' '435 Mitchell Street'
#  '15621 Twin Pines Crossing' '03 Bellgrove Avenue' '89100 Rusk Crossing'
#  '82 Gina Junction' '077 Dennis Lane' '42280 Namekagon Crossing'
#  '1 Fordem Way' '780 Bonner Pass' '77916 Moland Park'
#  '00 Southridge Avenue' '7870 Stuart Crossing' '4 Vera Pass'
#  '7234 Sycamore Pass' '98454 Dapin Park' '4 Talmadge Road' '47 Susan Park'
#  '7 Ramsey Trail' '6026 Mallory Drive' '1 Eliot Plaza' '66 Hoffman Court'
#  '7 Sycamore Terrace' '31281 Meadow Valley Way' '28 Parkside Park'
#  '2782 Northridge Street' '3662 Beilfuss Lane' '56334 Vera Crossing'
#  '79 Sheridan Point' '95960 Warner Parkway' '04769 Dahle Plaza'
#  '5731 Bunker Hill Lane' '89244 Macpherson Trail' '922 Utah Avenue'
#  '25044 Bay Avenue' '315 Hudson Road' '6112 Mariners Cove Park'
#  '176 Fallview Plaza' '544 Pawling Road' '11 Brickson Park Alley'
#  '77 Paget Park' '598 Memorial Place' '6227 Quincy Terrace'
#  '31351 Sunbrook Place' '80 Schiller Center' '1217 Melody Alley'
#  '46 Westerfield Place' '75024 Ronald Regan Hill' '15 Fisk Road'
#  '96 Hermina Place' '99376 Namekagon Street' '276 Derek Circle'
#  '56766 Mariners Cove Place' '13 Montana Place' '1969 Melody Lane'
#  '02463 Portage Center' '383 Graceland Avenue' '005 Kensington Street'
#  '1 Alpine Crossing' '2 Namekagon Trail' '6771 Pleasure Terrace'
#  '2632 Del Mar Point' '7021 5th Alley' '602 Clove Center'
#  '04153 Johnson Point' '9 Spohn Way' '6030 Becker Plaza' '4 Mallory Pass'
#  '64037 Swallow Crossing' '4594 Jackson Hill' '4 Anzinger Street'
#  '33 Pond Point' '1 Roth Plaza' '0593 Stoughton Center'
#  '8042 Cherokee Court' '5864 Mcbride Trail' '180 Lakewood Park'
#  '6 Union Center' '41153 Pond Park' '6233 Fulton Point'
#  '05123 Bobwhite Plaza' '3413 Schmedeman Court' '4189 Laurel Center'
#  '76 Melody Avenue' '1 Mcguire Lane' '8734 Fulton Hill'
#  '660 Hallows Place' '43 Pond Junction' '6195 Bellgrove Lane'
#  '768 Southridge Drive' '63386 Talisman Hill' '30738 Muir Avenue'
#  '3259 Eagan Parkway' '160 Fremont Point' '266 Lakewood Terrace'
#  '5280 Waxwing Point' '192 South Junction' '900 Victoria Way'
#  '06 Main Alley' '22 Muir Avenue' '4871 Caliangt Hill'
#  '47776 Packers Street' '535 Graedel Circle' '9 Stephen Center'
#  '074 Badeau Crossing' '4897 Melody Road' '096 Gateway Road'
#  '68 Bluestem Center' '6 Maple Plaza' '6812 Gina Point' '1 Becker Parkway'
#  '52201 Tony Avenue' '2382 Anthes Crossing' '44350 Buell Alley'
#  '23 Del Sol Alley' '79 Mockingbird Plaza' '858 Portage Hill'
#  '629 Grasskamp Junction' '88 Aberg Circle' '18 Morning Circle'
#  '7523 Eggendart Hill' '2 Mandrake Street' '727 Morrow Parkway'
#  '83497 Memorial Plaza' '488 Briar Crest Court' '78451 South Street'
#  '6 Prairieview Pass' '5 Ohio Road' '4787 Golf Terrace'
#  '4 Pine View Junction' '097 Hollow Ridge Alley' '860 Barby Lane'
#  '6412 Butternut Road' '15 Weeping Birch Crossing' '891 Sachtjen Hill'
#  '771 Union Crossing' '22 Farmco Avenue' '01 Bunker Hill Drive'
#  '7650 Gulseth Parkway' '24815 Lindbergh Avenue' '924 Lindbergh Court'
#  '1 Manitowish Court' '9 Derek Alley' '5990 Fairfield Pass'
#  '1 Mandrake Way' '4011 Prairieview Court' '53877 Dakota Crossing'
#  '49 Northfield Drive' '0 Summit Center' '66 Shopko Circle'
#  '370 Eastwood Road' '20 Hoffman Park' '6293 Hooker Point'
#  '30 Harper Trail' '64467 Pankratz Pass' '900 Brown Junction'
#  '8845 Spaight Way' '85420 Myrtle Road' '276 Anthes Court'
#  '6315 Mendota Parkway' '66904 American Ash Hill' '90 Morningstar Drive'
#  '34020 Sheridan Park' '58 Meadow Valley Court' '2030 Anderson Lane'
#  '07 Acker Pass' '31815 Vermont Drive' '5070 Division Parkway'
#  '4 Fordem Avenue' '659 Comanche Plaza' '5 Myrtle Junction'
#  '723 Grayhawk Way' '55 Dorton Point' '9 Killdeer Circle'
#  '04 Miller Drive' '64213 Miller Point' '24593 Jackson Parkway'
#  '9346 Lyons Point' '0504 Nevada Drive' '817 Loftsgordon Road'
#  '30 Lukken Point' '4 Kingsford Trail' '42 3rd Plaza'
#  '6660 Riverside Circle' '21712 Texas Court' '122 Marcy Park'
#  '293 Mendota Park' '47 Scofield Junction' '9 Washington Center'
#  '7109 Grayhawk Avenue' '70 Evergreen Hill' '20139 Lakewood Plaza'
#  '9 Memorial Road' '3094 Elka Place' '31 Schurz Parkway'
#  '85894 Amoth Court' '955 Burning Wood Way' '27 Crownhardt Center'
#  '41002 Loomis Park' '10 Cottonwood Point' '2115 Maryland Alley'
#  '6 Milwaukee Hill' '6792 Kropf Hill' '37 Mesta Road' '85340 Hovde Way'
#  '02643 Moose Court' '59252 Maryland Drive' '2886 Buena Vista Terrace'
#  '58770 Monterey Plaza' '2941 Loftsgordon Hill' '345 Fieldstone Park'
#  '251 Pierstorff Alley' '220 Cody Alley' '34 Bunting Pass'
#  '99 Park Meadow Hill' '4 Bluestem Pass' '078 Erie Point'
#  '6 Hansons Crossing' '8 Saint Paul Junction' '14067 Armistice Plaza'
#  '8491 Pennsylvania Crossing' '59208 Barnett Avenue'
#  '36 Killdeer Crossing' '305 Sloan Junction' '88 Shopko Way'
#  '7 Mallory Lane' '79907 Randy Center' '446 High Crossing Way'
#  '1530 Columbus Lane' '669 Declaration Street' '9 Ruskin Way'
#  '8 Burning Wood Junction' '5 Melvin Park' '21316 Ohio Place'
#  '93 Sutherland Terrace' '1560 Grim Avenue' '1 Quincy Road'
#  '607 Memorial Avenue' '9594 Badeau Street' '9460 Monument Park'
#  '72 Village Terrace' '694 Coolidge Center' '31854 Anniversary Terrace'
#  '125 Manufacturers Parkway' '260 Briar Crest Drive' '56 Moland Crossing'
#  '1 Shelley Pass' '0535 Jay Point' '6 Caliangt Way' '2 Sloan Way'
#  '04 Union Crossing' '33475 Fair Oaks Junction' '57666 Victoria Way'
#  '21875 Grover Drive']
#
# state cardinality -> 3
# ['QLD' 'NSW' 'VIC']
#
# country cardinality -> 1
# ['Australia']

# %% [markdown]
# gender column is having label = 'U

# %%
nw_cust_ls.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
remain_var = [var for var in nw_cust_ls.columns if var not in cat_var + ['first_name', 'last_name']]
num_var = remain_var[2:]
num_var = [var for var in num_var if 'Unnamed:' not in var]
num_var
# Out:
# ['tenure', 'postcode', 'property_valuation', 'Rank', 'Value']

# %%
nw_cust_ls[num_var].describe()
# Out:
#             tenure     postcode  property_valuation         Rank        Value
# count  1000.000000  1000.000000         1000.000000  1000.000000  1000.000000
# mean     11.388000  3019.227000            7.397000   498.819000     0.881714
# std       5.037145   848.895767            2.758804   288.810997     0.293525
# min       0.000000  2000.000000            1.000000     1.000000     0.340000
# 25%       7.000000  2209.000000            6.000000   250.000000     0.649531
# 50%      11.000000  2800.000000            8.000000   500.000000     0.860000
# 75%      15.000000  3845.500000            9.000000   750.250000     1.075000
# max      22.000000  4879.000000           12.000000  1000.000000     1.718750

# %%
num_boxplot(['tenure', 'property_valuation', 'Value'], nw_cust_ls)

# %% [markdown]
# The property_valuation column is having an outlier

# %%
# let's investigate into an outlier  
nw_cust_ls.property_valuation.quantile(np.arange(0.05,1.05,0.05))
# Out:
# 0.05     2.0
# 0.10     3.0
# 0.15     4.0
# 0.20     5.0
# 0.25     6.0
# 0.30     6.0
# 0.35     7.0
# 0.40     7.0
# 0.45     8.0
# 0.50     8.0
# 0.55     8.0
# 0.60     8.0
# 0.65     9.0
# 0.70     9.0
# 0.75     9.0
# 0.80    10.0
# 0.85    10.0
# 0.90    11.0
# 0.95    11.0
# 1.00    12.0
# Name: property_valuation, dtype: float64

# %%
nw_cust_ls[nw_cust_ls.property_valuation < 2]
# Out:
#     first_name   last_name  gender  past_3_years_bike_related_purchases  \
# 3       Lucine       Stutt  Female                                   64
# 35      Arleen     Casbolt  Female                                   48
# 46      Sheena      Kybbye  Female                                   14
# 108   Aridatha     Sephton  Female                                   95
# 126     Rebeca       Aggas  Female                                   66
# 127      Ricki   Dobrowski    Male                                   13
# 128  Georgetta      Lovett  Female                                   42
# 144      Glenn   Casbourne  Female                                    4
# 173      Paten       Cayet    Male                                   56
# 203  Rosemonde   Cartwight  Female                                   44
# 224    Wallace      Newart    Male                                   91
# 238    Leticia    Danovich  Female                                   84
# 289     Morton     Petkens    Male                                   50
# 325    Deirdre    Burgoine  Female                                   14
# 348      Caron       Kezar  Female                                   11
# 377    Harriet     Brattan  Female                                   81
# 419    Sherill         NaN  Female                                   33
# 440    Giralda    MacPeake  Female                                   59
# 488      Ariel     McCloid    Male                                    4
# 568     Oswald  MacCarlich    Male                                   81
# 584       Noel      Sturch  Female                                   26
# 635   Reinhard     Oscroft    Male                                   23
# 683      Selle      Casper  Female                                   98
# 739     Cecily    Faircley  Female                                   42
# 762     Yorgos    Dewhurst    Male                                    6
# 775     Dmitri       Viant       U                                   62
# 811      Rikki     Chaffey    Male                                   69
# 890       Shay      Briand    Male                                   57
# 968     Irving     Babcock    Male                                   60
# 981      Leona    Shorrock  Female                                   83
#
#            DOB                     job_title job_industry_category  \
# 3   1979-01-28    Account Representative III         Manufacturing
# 35  1975-05-10       Senior Quality Engineer    Financial Services
# 46  1956-07-16                     Paralegal    Financial Services
# 108 1961-10-22  Human Resources Assistant II                   NaN
# 126 1953-02-27                 Social Worker                Health
# 127 1975-03-10                Civil Engineer         Manufacturing
# 128 1940-02-02                        Editor                Retail
# 144 1981-08-08                 Senior Editor         Manufacturing
# 173 1995-02-19             Assistant Manager         Manufacturing
# 203 1952-10-20            Analyst Programmer                Retail
# 224 1977-12-06                           NaN                    IT
# 238 1941-10-02               Design Engineer         Entertainment
# 289 1990-11-13           Account Coordinator         Manufacturing
# 325 1955-01-08                Programmer III                Health
# 348 1953-08-08                 Social Worker                Health
# 377 1986-12-03   Human Resources Assistant I    Financial Services
# 419 1991-12-18   Information Systems Manager    Financial Services
# 440 1941-04-04                     Librarian         Entertainment
# 488 1994-03-13       Human Resources Manager                   NaN
# 568 1991-11-24       Assistant Media Planner         Entertainment
# 584 1951-10-28      Environmental Specialist                Health
# 635 1950-03-18                    Pharmacist                Health
# 683 1978-03-27                 Social Worker                Health
# 739 1947-06-12                 Accountant IV                    IT
# 762 1950-09-09           Software Consultant           Argiculture
# 775        NaT                     Paralegal    Financial Services
# 811 1945-06-11             Chemical Engineer         Manufacturing
# 890 1956-10-05               Project Manager                    IT
# 968 1986-01-17              Dental Hygienist                Health
# 981 1951-08-23       Senior Quality Engineer    Financial Services
#
#         wealth_segment deceased_indicator owns_car  tenure  \
# 3    Affluent Customer                  N      Yes       5
# 35   Affluent Customer                  N      Yes      13
# 46   Affluent Customer                  N      Yes      19
# 108      Mass Customer                  N       No       5
# 126  Affluent Customer                  N       No      21
# 127      Mass Customer                  N      Yes       9
# 128      Mass Customer                  N       No      12
# 144      Mass Customer                  N       No       6
# 173  Affluent Customer                  N      Yes      16
# 203      Mass Customer                  N      Yes       7
# 224      Mass Customer                  N       No      17
# 238      Mass Customer                  N      Yes      15
# 289     High Net Worth                  N      Yes      10
# 325     High Net Worth                  N       No       7
# 348      Mass Customer                  N       No       5
# 377     High Net Worth                  N       No       2
# 419      Mass Customer                  N       No       3
# 440     High Net Worth                  N      Yes      14
# 488     High Net Worth                  N      Yes       6
# 568      Mass Customer                  N       No      14
# 584      Mass Customer                  N       No      10
# 635     High Net Worth                  N       No      18
# 683      Mass Customer                  N      Yes      10
# 739  Affluent Customer                  N      Yes      19
# 762  Affluent Customer                  N       No      16
# 775  Affluent Customer                  N       No       5
# 811      Mass Customer                  N       No      20
# 890      Mass Customer                  N      Yes       9
# 968     High Net Worth                  N      Yes      15
# 981  Affluent Customer                  N      Yes      22
#
#                        address  postcode state    country  property_valuation  \
# 3           207 Annamark Plaza      4814   QLD  Australia                   1
# 35   41042 Lotheville Crossing      4817   QLD  Australia                   1
# 46        306 Clemons Junction      4852   QLD  Australia                   1
# 108         422 Forster Circle      2340   NSW  Australia                   1
# 126            7026 Katie Lane      3818   VIC  Australia                   1
# 127           8 Eggendart Pass      2835   NSW  Australia                   1
# 128            1 Bluejay Place      4405   QLD  Australia                   1
# 144             2 Morrow Alley      4207   QLD  Australia                   1
# 173      1398 Burning Wood Way      3850   VIC  Australia                   1
# 203             518 Paget Hill      4605   QLD  Australia                   1
# 224         29007 Dapin Street      4650   QLD  Australia                   1
# 238             2 Logan Avenue      4307   QLD  Australia                   1
# 289          385 Montana Place      3012   VIC  Australia                   1
# 325           0 Stoughton Park      3000   VIC  Australia                   1
# 348        40553 Rigney Avenue      2835   NSW  Australia                   1
# 377          66 Ruskin Parkway      3579   VIC  Australia                   1
# 419          53 Moulton Avenue      2880   NSW  Australia                   1
# 440             6 Killdeer Way      2705   NSW  Australia                   1
# 488          99 Quincy Parkway      3630   VIC  Australia                   1
# 568           16 Mosinee Place      4717   QLD  Australia                   1
# 584         0736 West Crossing      3585   VIC  Australia                   1
# 635        045 Magdeline Court      3690   VIC  Australia                   1
# 683                34 Jay Hill      2880   NSW  Australia                   1
# 739             8 Bluejay Road      4301   QLD  Australia                   1
# 762            4 Talmadge Road      4701   QLD  Australia                   1
# 775       95960 Warner Parkway      3842   VIC  Australia                   1
# 811                9 Spohn Way      4127   QLD  Australia                   1
# 890             1 Mandrake Way      3844   VIC  Australia                   1
# 968       36 Killdeer Crossing      2705   NSW  Australia                   1
# 981           1560 Grim Avenue      4720   QLD  Australia                   1
#
#      Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Rank  \
# 3           0.87       1.0875     1.087500     1.087500            4     4
# 35          0.77       0.9625     0.962500     0.962500           36    36
# 46          0.91       1.1375     1.137500     1.137500           46    46
# 108         0.93       0.9300     1.162500     0.988125          104   104
# 126         0.58       0.5800     0.580000     0.580000          127   127
# 127         0.89       1.1125     1.112500     0.945625          127   127
# 128         0.70       0.7000     0.700000     0.595000          127   127
# 144         0.90       0.9000     0.900000     0.765000          144   144
# 173         1.00       1.2500     1.250000     1.250000          174   174
# 203         1.00       1.2500     1.250000     1.062500          202   202
# 224         0.68       0.6800     0.850000     0.722500          223   223
# 238         1.03       1.2875     1.609375     1.367969          237   237
# 289         1.04       1.3000     1.300000     1.300000          289   289
# 325         0.81       0.8100     0.810000     0.810000          326   326
# 348         0.49       0.4900     0.490000     0.416500          349   349
# 377         0.84       0.8400     1.050000     1.050000          378   378
# 419         0.81       0.8100     0.810000     0.688500          420   420
# 440         0.93       1.1625     1.162500     1.162500          441   441
# 488         0.68       0.8500     0.850000     0.850000          486   486
# 568         0.78       0.7800     0.975000     0.828750          568   568
# 584         1.04       1.0400     1.040000     0.884000          583   583
# 635         0.58       0.5800     0.580000     0.580000          634   634
# 683         0.93       1.1625     1.453125     1.235156          684   684
# 739         1.10       1.3750     1.375000     1.375000          739   739
# 762         1.07       1.0700     1.070000     1.070000          760   760
# 775         0.86       0.8600     0.860000     0.860000          774   774
# 811         0.84       0.8400     0.840000     0.714000          810   810
# 890         1.09       1.3625     1.362500     1.158125          888   888
# 968         0.92       1.1500     1.150000     1.150000          967   967
# 981         0.44       0.5500     0.687500     0.687500          979   979
#
#         Value
# 3    1.703125
# 35   1.447656
# 46   1.407812
# 108  1.287500
# 126  1.250000
# 127  1.250000
# 128  1.250000
# 144  1.234375
# 173  1.168750
# 203  1.140625
# 224  1.115625
# 238  1.094375
# 289  1.037500
# 325  1.009375
# 348  0.987500
# 377  0.956250
# 419  0.913750
# 440  0.901000
# 488  0.875000
# 568  0.800000
# 584  0.787500
# 635  0.739500
# 683  0.700000
# 739  0.660000
# 762  0.637500
# 775  0.626875
# 811  0.587500
# 890  0.525000
# 968  0.435625
# 981  0.416500

# %%
nw_cust_ls[nw_cust_ls.property_valuation < 2].shape[0]/len(nw_cust_ls)*100
# Out:
# 3.0

# %%
# Customer first and last name having property_valuation < 2
list_pv = nw_cust_ls[nw_cust_ls.property_valuation < 2][['first_name', 'last_name']]
list_pv
# Out:
#     first_name   last_name
# 3       Lucine       Stutt
# 35      Arleen     Casbolt
# 46      Sheena      Kybbye
# 108   Aridatha     Sephton
# 126     Rebeca       Aggas
# 127      Ricki   Dobrowski
# 128  Georgetta      Lovett
# 144      Glenn   Casbourne
# 173      Paten       Cayet
# 203  Rosemonde   Cartwight
# 224    Wallace      Newart
# 238    Leticia    Danovich
# 289     Morton     Petkens
# 325    Deirdre    Burgoine
# 348      Caron       Kezar
# 377    Harriet     Brattan
# 419    Sherill         NaN
# 440    Giralda    MacPeake
# 488      Ariel     McCloid
# 568     Oswald  MacCarlich
# 584       Noel      Sturch
# 635   Reinhard     Oscroft
# 683      Selle      Casper
# 739     Cecily    Faircley
# 762     Yorgos    Dewhurst
# 775     Dmitri       Viant
# 811      Rikki     Chaffey
# 890       Shay      Briand
# 968     Irving     Babcock
# 981      Leona    Shorrock

# %%
list_pv.to_csv('first_last.csv')

# %%
plt.figure(figsize=(16,4))
nw_cust_ls.past_3_years_bike_related_purchases.hist(bins=30)

# %%
year_analyz(nw_cust_ls, 'DOB')

# %% [markdown]
# # Customers Demographics analysis

# %%
Cust_dmgrp = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',  sheet_name='CustomerDemographic', header=1)
Cust_dmgrp.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# 2              Property      Mass Customer                  N
# 3                    IT      Mass Customer                  N
# 4                   NaN  Affluent Customer                  N
#
#                                              default owns_car  tenure
# 0                                                 "'      Yes    11.0
# 1                       <script>alert('hi')</script>      Yes    16.0
# 2                                2018-02-01 00:00:00      Yes    15.0
# 3  () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No     7.0
# 4                                                NIL      Yes     8.0

# %%
Cust_dmgrp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
#  11  owns_car                             4000 non-null   object
#  12  tenure                               3913 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 406.4+ KB

# %%
sns.heatmap(Cust_dmgrp.corr())

# %%
Cust_dmgrp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
#  11  owns_car                             4000 non-null   object
#  12  tenure                               3913 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 406.4+ KB

# %% [markdown]
# Un recognizable column default

# %%
Cust_dmgrp.isnull().mean()*100
# Out:
# customer_id                             0.000
# first_name                              0.000
# last_name                               3.125
# gender                                  0.000
# past_3_years_bike_related_purchases     0.000
# DOB                                     2.175
# job_title                              12.650
# job_industry_category                  16.400
# wealth_segment                          0.000
# deceased_indicator                      0.000
# default                                 7.550
# owns_car                                0.000
# tenure                                  2.175
# dtype: float64

# %%
Cust_dmgrp.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
Cust_dmgrp[Cust_dmgrp['customer_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, default, owns_car, tenure]
# Index: []

# %%
cat_var = [var for var in Cust_dmgrp.columns if var not in num_var + ['first_name', 'last_name']]
cat_var
# Out:
# ['customer_id',
#  'gender',
#  'past_3_years_bike_related_purchases',
#  'DOB',
#  'job_title',
#  'job_industry_category',
#  'wealth_segment',
#  'deceased_indicator',
#  'default',
#  'owns_car']

# %%
cardinality(cat_var, Cust_dmgrp)
# Out:
# customer_id cardinality -> 4000
# [   1    2    3 ... 3998 3999 4000]
#
# gender cardinality -> 6
# ['F' 'Male' 'Female' 'U' 'Femal' 'M']
#
# past_3_years_bike_related_purchases cardinality -> 100
# [93 81 61 33 56 35  6 31 97 49 99 58 38 85 91 57 79 76 72 74 43 55 12 37
#   5 62 18  3 17 44 59 40 46 64 24 63 98 51 68 22  2 48 87 26 60 47 73 21
#  67 16 78 30 94 28 20 11  1 75 41 69 19 80 83 25 54  4 23 65 88 10 77  9
#  82 27 53 32 34 71 36 90 95  8 39  7 42 13 45 50 14 89 84 96 70 66  0 15
#  86 92 29 52]
#
# DOB cardinality -> 3448
# ['1953-10-12T00:00:00.000000000' '1980-12-16T00:00:00.000000000'
#  '1954-01-20T00:00:00.000000000' ... '1975-12-12T00:00:00.000000000'
#  '2001-07-13T00:00:00.000000000' '1991-11-05T00:00:00.000000000']
#
# job_title cardinality -> 195
# ['Executive Secretary' 'Administrative Officer' 'Recruiting Manager' nan
#  'Senior Editor' 'Media Manager I' 'Business Systems Development Analyst'
#  'Senior Quality Engineer' 'Nuclear Power Engineer' 'Developer I'
#  'Account Executive' 'Junior Executive' 'Media Manager IV'
#  'Sales Associate' 'Professor' 'Geological Engineer' 'Project Manager'
#  'Safety Technician I' 'Research Assistant I' 'Accounting Assistant III'
#  'Editor' 'Research Nurse' 'Safety Technician III' 'Staff Accountant III'
#  'Legal Assistant' 'Product Engineer' 'Information Systems Manager'
#  'VP Quality Control' 'Social Worker' 'Senior Cost Accountant'
#  'Assistant Media Planner' 'Payment Adjustment Coordinator' 'Food Chemist'
#  'Accountant III' 'Director of Sales' 'Senior Financial Analyst'
#  'Registered Nurse' 'Biostatistician II' 'Computer Systems Analyst II'
#  'Software Test Engineer II' 'Paralegal' 'VP Sales'
#  'Chief Design Engineer' 'Office Assistant III'
#  'Physical Therapy Assistant' 'Help Desk Operator' 'Web Developer II'
#  'Research Associate' 'Teacher' 'VP Product Management' 'Statistician II'
#  'Automation Specialist IV' 'Data Coordiator' 'Software Test Engineer III'
#  'Internal Auditor' 'Analyst Programmer' 'Occupational Therapist'
#  'Speech Pathologist' 'Quality Control Specialist' 'Civil Engineer'
#  'Software Engineer III' 'Community Outreach Specialist'
#  'Safety Technician IV' 'VP Accounting' 'General Manager'
#  'Nurse Practicioner' 'Automation Specialist II' 'Marketing Assistant'
#  'Marketing Manager' 'Staff Scientist' 'Assistant Professor'
#  'Budget/Accounting Analyst IV' 'Associate Professor' 'Graphic Designer'
#  'Administrative Assistant II' 'Compensation Analyst'
#  'Systems Administrator III' 'Financial Advisor' 'Chemical Engineer'
#  'Web Designer I' 'Senior Developer' 'Office Assistant II' 'Recruiter'
#  'Operator' 'Programmer Analyst III' 'Quality Engineer'
#  'Environmental Tech' 'Analog Circuit Design manager' 'Cost Accountant'
#  'Librarian' 'Structural Analysis Engineer' 'Pharmacist'
#  'Assistant Manager' 'Accountant I' 'Web Designer III' 'Geologist III'
#  'Software Test Engineer I' 'Structural Engineer' 'Safety Technician II'
#  'Web Developer III' 'Programmer Analyst II' 'Design Engineer'
#  'Statistician I' 'VP Marketing' 'Desktop Support Technician' 'Actuary'
#  'Database Administrator III' 'Electrical Engineer' 'Tax Accountant'
#  'Clinical Specialist' 'Database Administrator IV'
#  'Systems Administrator II' 'Account Coordinator' 'Programmer III'
#  'Administrative Assistant III' 'Nurse' 'Technical Writer'
#  'Staff Accountant II' 'Dental Hygienist' 'Sales Representative'
#  'Budget/Accounting Analyst III' 'Computer Systems Analyst IV'
#  'Geologist I' 'Financial Analyst' 'Accounting Assistant II'
#  'Senior Sales Associate' 'Database Administrator II' 'Engineer I'
#  'Budget/Accounting Analyst I' 'Developer IV' 'Database Administrator I'
#  'Environmental Specialist' 'Computer Systems Analyst I'
#  'Account Representative IV' 'Statistician IV' 'Human Resources Manager'
#  'GIS Technical Architect' 'Programmer IV' 'Accounting Assistant IV'
#  'Software Engineer IV' 'Programmer II' 'Engineer III'
#  'Software Consultant' 'Biostatistician IV' 'Help Desk Technician'
#  'Automation Specialist I' 'Developer III' 'Human Resources Assistant I'
#  'Geologist IV' 'Media Manager II' 'Statistician III' 'Engineer II'
#  'Health Coach II' 'Developer II' 'Systems Administrator I'
#  'Web Developer I' 'Software Engineer II' 'Accounting Assistant I'
#  'Research Assistant II' 'Programmer Analyst IV' 'Health Coach I'
#  'Accountant II' 'Automation Specialist III' 'Administrative Assistant I'
#  'Health Coach IV' 'Media Manager III' 'Account Representative III'
#  'Web Designer IV' 'Budget/Accounting Analyst II' 'Web Developer IV'
#  'Programmer I' 'Biostatistician III' 'Software Test Engineer IV'
#  'Research Assistant IV' 'Account Representative I' 'Accountant IV'
#  'Biostatistician I' 'Human Resources Assistant IV'
#  'Administrative Assistant IV' 'Office Assistant I'
#  'Human Resources Assistant II' 'Mechanical Systems Engineer'
#  'Engineer IV' 'Health Coach III' 'Office Assistant IV'
#  'Software Engineer I' 'Human Resources Assistant III'
#  'Staff Accountant I' 'Computer Systems Analyst III' 'Geologist II'
#  'Web Designer II' 'Staff Accountant IV' 'Account Representative II'
#  'Programmer Analyst I' 'Systems Administrator IV'
#  'Research Assistant III']
#
# job_industry_category cardinality -> 9
# ['Health' 'Financial Services' 'Property' 'IT' nan 'Retail' 'Argiculture'
#  'Manufacturing' 'Telecommunications' 'Entertainment']
#
# wealth_segment cardinality -> 3
# ['Mass Customer' 'Affluent Customer' 'High Net Worth']
#
# deceased_indicator cardinality -> 2
# ['N' 'Y']
#
# default cardinality -> 90
# ['"\'' "<script>alert('hi')</script>" datetime.datetime(2018, 2, 1, 0, 0)
#  '() { _; } >_[$($())] { touch /tmp/blns.shellshock2.fail; }' 'NIL'
#  'ðµ ð ð ð' 'â°â´âµâââ' '(â¯Â°â¡Â°ï¼â¯ï¸µ â»ââ»)' '0/0' 'ð©ð½'
#  'ÅâÂ´Â®â\xa0Â¥Â¨ËÃ¸Ïââ' 'nil' -100 'â°â´âµ' 'ð'
#  1000000000000000049861653971908893017010268485438462151574892930611988399099305815384459015356416
#  'ï¾ï½¥â¿ã¾â²(ï½¡ââ¿âï½¡)â±â¿ï½¥ï¾' 'Î©âÃ§ââ«ËÂµâ¤â¥Ã·' 'ÅâÂ´â°ËÃÂ¨ËÃâââ'
#  'ï¼ï¼ï¼' '../../../../../../../../../../../etc/hosts'
#  '×Ö¸×Ö°×ªÖ¸×testØ§ÙØµÙØ\xadØ§Øª Ø§ÙØªÙØ\xadÙÙ' '<>?:"{}|_+' '\'\'\'\'"'
#  ",./;'[]\\-=" '() { 0; }; touch /tmp/blns.shellshock1.fail;'
#  'ì¬íê³¼íì ì´íì°êµ¬ì' 'testâ\xa0testâ«'
#  '0ï¸â£ 1ï¸â£ 2ï¸â£ 3ï¸â£ 4ï¸â£ 5ï¸â£ 6ï¸â£ 7ï¸â£ 8ï¸â£ 9ï¸â£ ð' nan
#  '!@#$%^&*()' "'"
#  'Ì¦HÍÌ¬Ì¤ÌÌ¤eÍ ÍÌÌ¥ÌÌ»ÍÌwÌhÌÌ¯ÍoÌÍÌÍÌ±Ì® ÒÌºÌÌÌÍWÌ·Ì¼Ì\xadaÌºÌªÍiÌ¨ÍÍÌ\xadÍÌ¯ÌtÌ¶Ì¼Ì®sÌÌÍÍ Ì\xa0Ì«Ì\xa0BÌ»ÍÍÍÍÌ³eÌµhÌµÌ¬ÍÌ«ÍiÌÌ¹ÍÌ³Ì³Ì®ÍÌ«nÍdÌ´ÌªÌÌ ÍÌ°ÍÌ©ÍÍÍÌ²TÍ¢ÍÌ¼ÍÌªhÍÍÌ®Ì»eÌ¬ÌÍÌ Ì¤Ì¹ÌWÍÍÍÌÌÍÍaÍÍÍÌ¹Ì¼'
#  '../../../../../../../../../../../etc/passwd%00' 'åè£½æ¼¢èª'
#  '`ââ¬â¹âºï¬ï¬â¡Â°Â·ââÂ±' 'ãã¼ãã£ã¼ã¸è¡ããªãã' 1 -0.5
#  'ZÌ®ÌÍÌ\xa0ÍÍAÌ¥ÌÌÍÌ»ÌLÌ£ÍÍÌ¯Ì¹ÌÍGÌ»OÌ\xadÌÌ®' 'ã' 100
#  '1;DROP TABLE users' -1 'á' '(ï¾à²¥çà²¥ï¼ï¾ï»¿ â»ââ»' '00ËÆ$-' '1/0'
#  'ï½ï½¨(Â´âï½â©' "<svg><script>0<1>alert('XSS')</script>" 'âââ'
#  'ã»(ï¿£âï¿£)ã»:*:' ',ãã»:*:ã»ãâ( â» Ï â» )ãã»:*:ã»ãâ' 'â¢'
#  'ç°ä¸\xadããã«ããã¦ä¸ãã' '__ï¾(,_,*)' 'Ù¡Ù¢Ù£'
#  'Ø«Ù ÙÙØ³ Ø³ÙØ·Øª ÙØ¨Ø§ÙØªØ\xadØ¯ÙØ¯Ø, Ø¬Ø²ÙØ±ØªÙ Ø¨Ø§Ø³ØªØ®Ø¯Ø§Ù Ø£Ù Ø¯ÙÙ. Ø¥Ø° ÙÙØ§Ø Ø§ÙØ³ØªØ§Ø± ÙØªÙØµÙØ¨ ÙØ§Ù. Ø£ÙÙÙ Ø§ÙØ·Ø§ÙÙØ§Ø Ø¨Ø±ÙØ·Ø§ÙÙØ§-ÙØ±ÙØ³Ø§ ÙØ¯ Ø£Ø®Ø°. Ø³ÙÙÙØ§ÙØ Ø¥ØªÙØ§ÙÙØ© Ø¨ÙÙ ÙØ§, ÙØ°ÙØ± Ø'
#  'ð¾ ð ð ð ð ð ð ð§' "<img src=x onerror=alert('hi') />"
#  'ã½à¼¼àºÙÍàºà¼½ï¾ ã½à¼¼àºÙÍàºà¼½ï¾' 'âð¿ ðªð¿ ðð¿ ðð¿ ðð¿ ðð¿'
#  'TÌÌ\xadÌºÌºoÍ Ì·iÌ²Ì¬ÍÌªÍnÌÌÍvÍÌÌÌÌ¦oÌ¶ÌÌ°Ì\xa0keÍÍÌ®ÌºÌªÌ¹Ì±Ì¤ ÌtÍÌÍÌ³Ì£Ì»ÌªhÌ¼ÍÌ²Ì¦Ì³ÌÌ²eÍÌ£Ì°Ì¦Ì¬Í Ì¢Ì¼Ì»Ì±ÌhÍÍÍÍÌÌ£Ì²iÌ¦Ì²Ì£Ì°Ì¤vÌ»ÍeÌºÌ\xadÌ³ÌªÌ°-mÌ¢iÍnÌÌºÌÌ²Ì¯Ì°dÌµÌ¼ÌÍÌ©Ì¼ÌÌ³ ÌÌ¥Ì±Ì³Ì\xadrÌÌÌeÍpÍ\xa0rÌ¼ÌÌ»Ì\xadÌeÍÌºÌ\xa0Ì£sÌ'
#  'ÃÃÃÃËÃÃï£¿ÃÃÃâ' '(ï½¡â â âï½¡)' 'é¨è½æ\xa0¼'
#  "ËÉnbá´lÉ ÉuÆÉÉ¯ ÇÉ¹olop ÊÇ ÇÉ¹oqÉl Ên Êunpá´pá´Éuá´ É¹odÉ¯ÇÊ poÉ¯sná´Ç op pÇs 'Êá´lÇ Æuá´Ésá´dá´pÉ É¹nÊÇÊÉÇsuoÉ 'ÊÇÉ¯É Êá´s É¹olop É¯nsdá´ É¯ÇÉ¹oË¥"
#  'á\xa0'
#  '×Ö¼Ö°×¨Öµ××©×Ö´××ª, ×Ö¼Ö¸×¨Ö¸× ×Ö±×Ö¹×Ö´××, ×Öµ×ª ×Ö·×©Ö¼×Ö¸×Ö·×Ö´×, ×Ö°×Öµ×ª ×Ö¸×Ö¸×¨Ö¶×¥'
#  'Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ\xa0' '/dev/null; touch /tmp/blns.fail ; echo'
#  "1'; DROP TABLE users--" 'ð¾ ð ð ð ð ð ð ð'
#  'Ì¡ÍÍÌIÍÌÌÌ¦nÍÍÍvÌ®Ì«okÌ²Ì«ÌÍiÌÍÌ\xadÌ¹Ì\xa0ÌnÌ¡Ì»Ì®Ì£ÌºgÌ²ÍÍÌ\xadÍÌ¬Í Ì°tÍÌ¦hÌÌ²eÌ¢Ì¤ ÍÌ¬Ì²ÍfÌ´ÌÍÌ£eÍÍeÌ£Ì¥Ì©lÍÍÍiÍ\xa0ÍÍÌ¦nÍÍÌÍÌ³Ì®gÍ Ì¨oÍ¡ÍÌªfÌÌ£Ì¬ ÌÌÍÌÍÌ®cÒÍÌ«ÍÍÍÍÍhÌµÌ¤Ì£ÍÍaÍÌÌ¼ÍÍoÌ¼Ì£Ì¥sÍ¢Ì±ÍÌºÌÌ¦Ì».ÌÌ'
#  'â' 'Â¸ËÃâÄ±ËÃÂ¯ËÂ¿' 'ì¸ëë°í\xa0ë¥´'
#  'ÌÌºÍÌ¹Ì¯ÍTÌ±Ì¤ÍÌ¥ÍÍhÍÌ²eÍÍÌ¼ÌÌÌ¼Ì£Í ÍÌÌ±Ì\xa0ÍÍÍNÍ\xa0ÍeÌÌ±zÌÌÌÌºÍpÌ¤ÌºÌ¹ÍÌ¯ÍeÍÌ\xa0Ì»Ì\xa0rÌ¨Ì¤ÍÌºÌÍÌÌdÍÌ\xa0ÌÌ\xadÌ¬ÌiÌ¦ÍÌ©ÍÍÌ¤aÌ\xa0ÌÌ¬ÍÌnÍÍ Ì»ÌÌ°ÍÍhÌµÍiÌ³ÌvÌ¢ÍeÍÌ\xadÍ-ÒÌ\xadÌ©Ì¼ÍmÌ¤Ì\xadÌ«iÍÍÌÌ¦nÌÍdÌ£Ì ÍÌ¯Ì²ÍoÌ¨ÌÌ¯Ì°Ì²'
#  0 'â©testâ©' 'â£' 'Ã¥ÃâÆÂ©ËâËÂ¬â¦Ã¦' 'ç¤¾æç§å\xad¸é¢èªå\xad¸ç\xa0ç©¶æ'
#  'âªâªtestâª' 'ï»¿' 'â¤ï¸ ð ð ð ð ð ð ð ð ð ð ð ð ð ð' 'â«testâ«'
#  'â¦testâ§' '\'"\'\'\'\'"' 'â¡'
#  'ð\xa0ð\xa0±ð\xa0¹ð\xa0±ð\xa0±¸ð\xa0²ð\xa0³']
#
# owns_car cardinality -> 2
# ['Yes' 'No']

# %% [markdown]
# * different labels for same category in gender column

# %%
num_var =[var for var in Cust_dmgrp.columns if Cust_dmgrp[var].dtypes != 'object']
num_var
# Out:
# ['customer_id', 'past_3_years_bike_related_purchases', 'DOB', 'tenure']

# %%
num_boxplot(['past_3_years_bike_related_purchases', 'tenure'], Cust_dmgrp)

# %%
year_analyz(Cust_dmgrp, 'DOB')

# %% [markdown]
# One outlier in DOB column ie year 1843

# %%
# Customer information having Date of birth in year 1834
Cust_dmgrp.iloc[33,:]
# Out:
# customer_id                                             34
# first_name                                        Jephthah
# last_name                                         Bachmann
# gender                                                   U
# past_3_years_bike_related_purchases                     59
# DOB                                    1843-12-21 00:00:00
# job_title                                  Legal Assistant
# job_industry_category                                   IT
# wealth_segment                           Affluent Customer
# deceased_indicator                                       N
# default                                                NaN
# owns_car                                                No
# tenure                                                  20
# Name: 33, dtype: object

# %% [markdown]
# # Customer's Address

# %%
address = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx',  sheet_name='CustomerAddress', header=1)
address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
address.isnull().mean()*100
# Out:
# customer_id           0.0
# address               0.0
# postcode              0.0
# state                 0.0
# country               0.0
# property_valuation    0.0
# dtype: float64

# %%
address[address['customer_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, address, postcode, state, country, property_valuation]
# Index: []

# %%
address.duplicated().sum()
# Out:
# 0

# %%
cardinality(['state', 'country'], address)
# Out:
# state cardinality -> 5
# ['New South Wales' 'QLD' 'VIC' 'NSW' 'Victoria']
#
# country cardinality -> 1
# ['Australia']

# %% [markdown]
# The state column is having different labels for same categories

# %%
num_boxplot(['property_valuation'], address)

# %%
address['postcode'].describe()
# Out:
# count    3999.000000
# mean     2985.755939
# std       844.878364
# min      2000.000000
# 25%      2200.000000
# 50%      2768.000000
# 75%      3750.000000
# max      4883.000000
# Name: postcode, dtype: float64

# %%
sns.heatmap(address.corr())
