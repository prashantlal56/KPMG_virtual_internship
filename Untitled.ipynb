# %%
# Importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
# Configuring default setting to display all the rows and columns
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
# loading dataset
transaction = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='Transactions', header=1)
demographic = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='CustomerDemographic', header=1)
address = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='CustomerAddress', header=1)

# %%
# visualise data set
transaction.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
# visualise data set
demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
# visualise data set
address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
transaction.customer_id.nunique()
# Out:
# 3494

# %%
demographic.customer_id.nunique()
# Out:
# 4000

# %%
address.customer_id.nunique()
# Out:
# 3999

# %%
[id for id in demographic.customer_id.unique() if id not in transaction.customer_id.unique()]
# Out:
# [852,
#  869,
#  1373,
#  2074,
#  2660,
#  3229,
#  3236,
#  3501,
#  3502,
#  3503,
#  3504,
#  3505,
#  3506,
#  3507,
#  3508,
#  3509,
#  3510,
#  3511,
#  3512,
#  3513,
#  3514,
#  3515,
#  3516,
#  3517,
#  3518,
#  3519,
#  3520,
#  3521,
#  3522,
#  3523,
#  3524,
#  3525,
#  3526,
#  3527,
#  3528,
#  3529,
#  3530,
#  3531,
#  3532,
#  3533,
#  3534,
#  3535,
#  3536,
#  3537,
#  3538,
#  3539,
#  3540,
#  3541,
#  3542,
#  3543,
#  3544,
#  3545,
#  3546,
#  3547,
#  3548,
#  3549,
#  3550,
#  3551,
#  3552,
#  3553,
#  3554,
#  3555,
#  3556,
#  3557,
#  3558,
#  3559,
#  3560,
#  3561,
#  3562,
#  3563,
#  3564,
#  3565,
#  3566,
#  3567,
#  3568,
#  3569,
#  3570,
#  3571,
#  3572,
#  3573,
#  3574,
#  3575,
#  3576,
#  3577,
#  3578,
#  3579,
#  3580,
#  3581,
#  3582,
#  3583,
#  3584,
#  3585,
#  3586,
#  3587,
#  3588,
#  3589,
#  3590,
#  3591,
#  3592,
#  3593,
#  3594,
#  3595,
#  3596,
#  3597,
#  3598,
#  3599,
#  3600,
#  3601,
#  3602,
#  3603,
#  3604,
# ...

# %%
[id for id in transaction.customer_id.unique() if id not in demographic.customer_id.unique()]
# Out:
# [5034]

# %%
[id for id in demographic.customer_id.unique() if id not in address.customer_id.unique()]
# Out:
# [3, 10, 22, 23]

# %%
[id for id in address.customer_id.unique() if id not in demographic.customer_id.unique()]
# Out:
# [4001, 4002, 4003]

# %%
[id for id in transaction.customer_id.unique() if id not in demographic.customer_id.unique() and id not in address.customer_id.unique()]
# Out:
# [5034]

# %%
df = pd.merge(demographic, transaction, how='inner', on='customer_id')
df.head()
# Out:
#    customer_id first_name  last_name gender  \
# 0            1    Laraine  Medendorp      F
# 1            1    Laraine  Medendorp      F
# 2            1    Laraine  Medendorp      F
# 3            1    Laraine  Medendorp      F
# 4            1    Laraine  Medendorp      F
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   93 1953-10-12  Executive Secretary
# 1                                   93 1953-10-12  Executive Secretary
# 2                                   93 1953-10-12  Executive Secretary
# 3                                   93 1953-10-12  Executive Secretary
# 4                                   93 1953-10-12  Executive Secretary
#
#   job_industry_category wealth_segment deceased_indicator default owns_car  \
# 0                Health  Mass Customer                  N      "'      Yes
# 1                Health  Mass Customer                  N      "'      Yes
# ...

# %%
df = pd.merge(df, address, how= 'inner', on='customer_id')
df.head()
# Out:
#    customer_id first_name  last_name gender  \
# 0            1    Laraine  Medendorp      F
# 1            1    Laraine  Medendorp      F
# 2            1    Laraine  Medendorp      F
# 3            1    Laraine  Medendorp      F
# 4            1    Laraine  Medendorp      F
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   93 1953-10-12  Executive Secretary
# 1                                   93 1953-10-12  Executive Secretary
# 2                                   93 1953-10-12  Executive Secretary
# 3                                   93 1953-10-12  Executive Secretary
# 4                                   93 1953-10-12  Executive Secretary
#
#   job_industry_category wealth_segment deceased_indicator default owns_car  \
# 0                Health  Mass Customer                  N      "'      Yes
# 1                Health  Mass Customer                  N      "'      Yes
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure', 'transaction_id', 'product_id',
#        'transaction_date', 'online_order', 'order_status', 'brand',
#        'product_line', 'product_class', 'product_size', 'list_price',
#        'standard_cost', 'product_first_sold_date', 'address', 'postcode',
#        'state', 'country', 'property_valuation'],
#       dtype='object')
